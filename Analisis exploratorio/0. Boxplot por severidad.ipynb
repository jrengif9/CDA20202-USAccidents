# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder    #tranforma variables categoricas a numericas
from sklearn.preprocessing import StandardScaler  # Escala los datos
import pickle

# %%
path = 'C:\\Users\\USER\\OneDrive - Universidad EAFIT\\Semestre 1 2020-2\\Proyecto Integrados Semestre 1\\Datos PI - ARI\\'
archivo = 'cleanedVariables-standarized-respuestaBinaria.pkl'
rutaArchivo = path + archivo
df = pd.read_pickle(rutaArchivo)

# %%
df_Num=df.select_dtypes(include=["float", 'int'])

# %%
df_Num['Severity']=df['Severity']
# Out:
# <ipython-input-4-0c5b3ee3616e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Num['Severity']=df['Severity']

# %%
df_Num=df_Num.drop(['newSeverity'], axis=1)

# %%
df_Num.columns
# Out:
# Index(['Start_Lat', 'Start_Lng', 'Temperature(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)', 'Severity'],
#       dtype='object')

# %%
# %%time
boxplot = df_Num.boxplot(by='Severity',figsize= (15,15))
# Out:
# Wall time: 4.86 s

# %%
boxplot = df_Num.boxplot('Temperature(F)',by='Severity',figsize= (15,15))

# %%
boxplot = df_Num.boxplot('Humidity(%)',by='Severity',figsize= (15,15))

# %%
boxplot = df_Num.boxplot('Pressure(in)',by='Severity',figsize= (15,15))

# %%
boxplot = df_Num.boxplot('Visibility(mi)',by='Severity',figsize= (15,15))

# %%
boxplot = df_Num.boxplot('Wind_Speed(mph)',by='Severity',figsize= (15,15))
ylim=(0,15)

# %%
boxplot = df_Num.boxplot('Wind_Speed(mph)',by='Severity',figsize= (15,15))
