# %% [markdown]
# # Leer datos

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import LabelEncoder    #tranforma variables categoricas a numericas
from sklearn.preprocessing import StandardScaler  # Escala los datos
import pickle

# %%
path = 'C:\\Users\\USER\\OneDrive - Universidad EAFIT\\Semestre 1 2020-2\\Proyecto Integrados Semestre 1\\Datos PI - ARI\\'
archivo = 'cleanedVariables-standarized-respuestaBinaria.pkl'
rutaArchivo = path + archivo
df = pd.read_pickle(rutaArchivo)

# %% [markdown]
# # 1. Scatterplot

# %%
df_Num=df.select_dtypes(include=["float", 'int'])

# %%
df_Num.drop(['newSeverity'], axis=1)
# Out:
#          Start_Lat   Start_Lng  Temperature(F)  Humidity(%)  Pressure(in)  \
# 0        39.063148  -84.032608       -1.413528     1.584296     -0.040193
# 1        39.747753  -84.205582       -1.461671     1.407576     -0.074852
# 2        39.627781  -84.188354       -1.413528     1.098315     -0.063299
# 3        40.100590  -82.925194       -1.311892     1.451756     -0.086405
# 4        39.758274  -84.230507       -1.520513     1.584296     -0.051746
# ...            ...         ...             ...          ...           ...
# 3027848  34.002480 -117.379360        1.261096    -1.066513     -0.906669
# 3027849  32.766960 -117.148060        0.405217     0.391432     -0.363677
# 3027850  33.775450 -117.847790        0.565694    -0.006189      0.040678
# 3027851  33.992460 -118.403020        0.458709     0.744873     -0.097958
# 3027852  34.133930 -117.230920        0.886649    -0.757252     -1.241706
#
#          Visibility(mi)  Wind_Speed(mph)
# ...

# %%
df_Num.columns
# Out:
# Index(['Start_Lat', 'Start_Lng', 'newSeverity', 'Temperature(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)'],
#       dtype='object')

# %%
df_Num['Severity']=df['Severity']
# Out:
# <ipython-input-50-0c5b3ee3616e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_Num['Severity']=df['Severity']

# %%
df_Num.columns
# Out:
# Index(['Start_Lat', 'Start_Lng', 'newSeverity', 'Temperature(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)',
#        'Severity'],
#       dtype='object')

# %%
# %%time
sns.pairplot(df_Num, hue="Severity",markers=["o", "s"],corner=True,height=1.5)
plt.show()

# %% [markdown]
# ###  (sin 'newSeverity')

# %%
df_Num=df_Num.drop(['newSeverity'],axis=1)

# %%
df_Num.columns
# Out:
# Index(['Start_Lat', 'Start_Lng', 'Temperature(F)', 'Humidity(%)',
#        'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)', 'Severity'],
#       dtype='object')

# %%
# %%time
sns.pairplot(df_Num, hue="Severity",markers=["o", "s"],corner=True,height=1.5)
plt.show()
# Out:
# Wall time: 45min 32s
